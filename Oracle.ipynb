# %% [markdown]
# #Random Forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# #Training Data

# %%
#load the dataset
data=pd.read_csv("/content/Training set.csv")
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Monthly_Inhand_Salary   Accounts of user  \
# 0        5279          5279             4377.072500                10
# 1         473           473             2184.576667                 8
# 2        1355          1355             1837.084167                 3
# 3        1546          1546             6867.951667                 5
# 4        1323          1323             1089.858750                 4
#
#    Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# 0                       6             27            6                   35
# 1                       6             32            7                   51
# 2                       7              3            2                   14
# 3                       4              9            1                    6
# 4                       7              4            2                   12
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Outstanding_Debt  \
# ...

# %%
data.shape
# Out:
# (6094, 19)

# %%
X = data.drop('Credit Score', axis=1).values
y = data['Credit Score'].values

# %%
#split the data into training and testing data
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %% [markdown]
# fitting the model

# %%
model = RandomForestClassifier(n_estimators=15,criterion='entropy')
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=15)

# %%
#scaling the testing data
y_pred = model.predict(X_test)

# %%
model.score(X_train, y_train)
# Out:
# 0.9989743589743589

# %%
model.score(X_test, y_test)
# Out:
# 0.9368334700574241

# %%
#confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[759,   3,  28],
#        [  5, 132,  12],
#        [ 23,   6, 251]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Best       0.96      0.96      0.96       790
#         Good       0.94      0.89      0.91       149
#     Standard       0.86      0.90      0.88       280
#
#     accuracy                           0.94      1219
#    macro avg       0.92      0.91      0.92      1219
# weighted avg       0.94      0.94      0.94      1219

# %% [markdown]
# #Testing Data

# %%
#load the dataset
data1=pd.read_csv("/content/Test SET.csv")
data1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Monthly_Inhand_Salary   Accounts of user  \
# 0        7531          7531             3520.621667                 7
# 1        1914          1914             2455.479851                 3
# 2        1282          1282              592.179167                 6
# 3        5517          5517             4976.090000                 9
# 4        3610          3610             1720.165833                 7
#
#    Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# 0                       6             28            9                   32
# 1                       5              5            3                    9
# 2                       5             29            3                   41
# 3                       7             30            9                   26
# 4                       9             32            4                   47
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Outstanding_Debt  \
# ...

# %%
data1.shape
# Out:
# (1524, 18)

# %%
data1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Monthly_Inhand_Salary   Accounts of user  \
# 0           7531          7531             3520.621667                 7
# 1           1914          1914             2455.479851                 3
# 2           1282          1282              592.179167                 6
# 3           5517          5517             4976.090000                 9
# 4           3610          3610             1720.165833                 7
# ...          ...           ...                     ...               ...
# 1519        7258          7258            11418.936670                 4
# 1520         280           280             2582.813333                 7
# 1521        3285          3285             1637.780833                 2
# 1522        5567          5567             4622.948333                 5
# 1523          51            51             1512.361667                 6
#
#       Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# ...

# %%
from collections import Counter

# %%
l=[] 
l.append('Best') 
for i in range(1,1524):   
  k=data1.head(i)   
  output = model.predict(k)   
  d=Counter(list(output))
  Keymax = max(zip(d.values(), d.keys()))[1]
  l.append(Keymax)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ...

# %%
data1['Credit Score']=l

# %%
data1
# Out:
#       Unnamed: 0  Unnamed: 0.1  Monthly_Inhand_Salary   Accounts of user  \
# 0           7531          7531             3520.621667                 7
# 1           1914          1914             2455.479851                 3
# 2           1282          1282              592.179167                 6
# 3           5517          5517             4976.090000                 9
# 4           3610          3610             1720.165833                 7
# ...          ...           ...                     ...               ...
# 1519        7258          7258            11418.936670                 4
# 1520         280           280             2582.813333                 7
# 1521        3285          3285             1637.780833                 2
# 1522        5567          5567             4622.948333                 5
# 1523          51            51             1512.361667                 6
#
#       Credit cards user have  Interest Rate  Num_of_Loan  Delay_from_due_date  \
# ...

# %%
data1.shape
# Out:
# (1524, 19)

# %%
X1 = data1.drop('Credit Score', axis=1).values
y1 = data1['Credit Score'].values

# %%
X_train1, X_test1, y_train1, y_test1=train_test_split(X1,y1,test_size=0.2,random_state=45)

# %%
model.fit(X_train1, y_train1)
y_pred1 = model.predict(X_test1)
# Out:
#               precision    recall  f1-score   support
#
#         Best       1.00      1.00      1.00       304
#     Standard       0.00      0.00      0.00         1
#
#     accuracy                           1.00       305
#    macro avg       0.50      0.50      0.50       305
# weighted avg       0.99      1.00      1.00       305
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
model.score(X_train1, y_train1)
# Out:
# 0.9991796554552912

# %%
model.score(X_test1, y_test1)
# Out:
# 0.9967213114754099

# %%
confusion_matrix(y_test1, y_pred1)
# Out:
# array([[304,   0],
#        [  1,   0]])

# %%
print(classification_report(y_test1, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#         Best       1.00      1.00      1.00       304
#     Standard       0.00      0.00      0.00         1
#
#     accuracy                           1.00       305
#    macro avg       0.50      0.50      0.50       305
# weighted avg       0.99      1.00      1.00       305
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# #Conclusion

# %% [markdown]
#  TRAINING SET : The accuracy of training data is 0.998 and for the testing data is 0.936
#
#
#
#
# TESTING SET   : The accuracy of training data is 0.999 and for the testing data is 0.996
